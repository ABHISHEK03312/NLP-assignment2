# %%
import pandas as pd
import pylab as plt
import numpy as np

# %%
cnn_1_layer_train = pd.read_csv("/Users/abhishekvaidyanathan/Desktop/NLP-assignment2/1-CNN-layer/1Train.csv")
cnn_1_layer_dev = pd.read_csv("/Users/abhishekvaidyanathan/Desktop/NLP-assignment2/1-CNN-layer/1Dev.csv")
cnn_1_layer_test = pd.read_csv("/Users/abhishekvaidyanathan/Desktop/NLP-assignment2/1-CNN-layer/1Test.csv")
cnn_3_layer_train = pd.read_csv("/Users/abhishekvaidyanathan/Desktop/NLP-assignment2/3-CNN-layer/3Train.csv")
cnn_3_layer_dev = pd.read_csv("/Users/abhishekvaidyanathan/Desktop/NLP-assignment2/3-CNN-layer/3Dev.csv")
cnn_3_layer_test = pd.read_csv("/Users/abhishekvaidyanathan/Desktop/NLP-assignment2/3-CNN-layer/3Test.csv")
cnn_5_layer_train = pd.read_csv("/Users/abhishekvaidyanathan/Desktop/NLP-assignment2/5-CNN-layer/5Train.csv")
cnn_5_layer_dev = pd.read_csv("/Users/abhishekvaidyanathan/Desktop/NLP-assignment2/5-CNN-layer/5Dev.csv")
cnn_5_layer_test = pd.read_csv("/Users/abhishekvaidyanathan/Desktop/NLP-assignment2/5-CNN-layer/5Test.csv")

# %%
cnn_1_layer_dev.head()
# Out:
#    correct_preds  total_preds  total_correct     new_F    best_F
# 0         5209.0       5913.0         5939.0  0.879008  0.879008
# 1         5092.0       5621.0         5939.0  0.880969  0.880969
# 2         5204.0       5880.0         5939.0  0.880616  0.880969
# 3         5243.0       5803.0         5939.0  0.893034  0.893034
# 4         5262.0       5719.0         5939.0  0.902728  0.902728

# %%
plt.figure(1)
plt.plot(cnn_1_layer_train['new_F'])
plt.plot(cnn_1_layer_test['new_F'])
plt.plot(cnn_1_layer_dev['new_F'])
plt.title('F1 score 1 layer CNN')
plt.ylabel('F1 score')
plt.xlabel('epoch')
plt.legend(['train', 'test','dev'], loc='lower right')
plt.show()

plt.figure(2)
plt.plot(cnn_3_layer_train['new_F'])
plt.plot(cnn_3_layer_test['new_F'])
plt.plot(cnn_3_layer_dev['new_F'])
plt.title('F1 score 3 layer CNN')
plt.ylabel('F1 score')
plt.xlabel('epoch')
plt.legend(['train', 'test','dev'], loc='lower right')
plt.show()

plt.figure(3)
plt.plot(cnn_5_layer_train['new_F'])
plt.plot(cnn_5_layer_test['new_F'])
plt.plot(cnn_5_layer_dev['new_F'])
plt.title('F1 score 5 layer CNN')
plt.ylabel('F1 score')
plt.xlabel('epoch')
plt.legend(['train', 'test','dev'], loc='lower right')
plt.show()

# %%
plt.figure(4)
plt.plot(cnn_1_layer_train['new_F'])
plt.plot(cnn_3_layer_train['new_F'])
plt.plot(cnn_5_layer_train['new_F'])
plt.title('F1 score train')
plt.ylabel('F1 score')
plt.xlabel('epoch')
plt.legend(['1 layer CNN', '3 layer CNN','5 layer CNN'], loc='lower right')
plt.show()

plt.figure(5)
plt.plot(cnn_1_layer_dev['new_F'])
plt.plot(cnn_3_layer_dev['new_F'])
plt.plot(cnn_5_layer_dev['new_F'])
plt.title('F1 score dev')
plt.ylabel('F1 score')
plt.xlabel('epoch')
plt.legend(['1 layer CNN', '3 layer CNN','5 layer CNN'], loc='lower right')
plt.show()

plt.figure(6)
plt.plot(cnn_1_layer_test['new_F'])
plt.plot(cnn_3_layer_test['new_F'])
plt.plot(cnn_5_layer_test['new_F'])
plt.title('F1 score test')
plt.ylabel('F1 score')
plt.xlabel('epoch')
plt.legend(['1 layer CNN', '3 layer CNN','5 layer CNN'], loc='lower right')
plt.show()

# %%
plt.figure(7)
plt.plot(cnn_1_layer_train['correct_preds']/cnn_1_layer_train['total_correct'])
plt.plot(cnn_1_layer_test['correct_preds']/cnn_1_layer_test['total_correct'])
plt.plot(cnn_1_layer_dev['correct_preds']/cnn_1_layer_dev['total_correct'])
plt.title('accuracy 1 layer CNN')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test','dev'], loc='lower right')
plt.show()

plt.figure(8)
plt.plot(cnn_3_layer_train['correct_preds']/cnn_3_layer_train['total_correct'])
plt.plot(cnn_3_layer_test['correct_preds']/cnn_3_layer_test['total_correct'])
plt.plot(cnn_3_layer_dev['correct_preds']/cnn_3_layer_dev['total_correct'])
plt.title('accuracy 3 layer CNN')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test','dev'], loc='lower right')
plt.show()

plt.figure(9)
plt.plot(cnn_5_layer_train['correct_preds']/cnn_5_layer_train['total_correct'])
plt.plot(cnn_5_layer_test['correct_preds']/cnn_5_layer_test['total_correct'])
plt.plot(cnn_5_layer_dev['correct_preds']/cnn_5_layer_dev['total_correct'])
plt.title('accuracy 5 layer CNN')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test','dev'], loc='lower right')
plt.show()

# %%
plt.figure(10)
plt.plot(cnn_1_layer_train['correct_preds']/cnn_1_layer_train['total_correct'])
plt.plot(cnn_3_layer_train['correct_preds']/cnn_3_layer_train['total_correct'])
plt.plot(cnn_5_layer_train['correct_preds']/cnn_5_layer_train['total_correct'])
plt.title('accuracy for different models')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['1 layer CNN', '3 layer CNN','5 layer CNN'], loc='lower right')
plt.show()

plt.figure(11)
plt.plot(cnn_1_layer_test['correct_preds']/cnn_1_layer_test['total_correct'])
plt.plot(cnn_3_layer_test['correct_preds']/cnn_3_layer_test['total_correct'])
plt.plot(cnn_5_layer_test['correct_preds']/cnn_5_layer_test['total_correct'])
plt.title('accuracy for different models')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['1 layer CNN', '3 layer CNN','5 layer CNN'], loc='lower right')
plt.show()

plt.figure(12)
plt.plot(cnn_1_layer_dev['correct_preds']/cnn_1_layer_dev['total_correct'])
plt.plot(cnn_3_layer_dev['correct_preds']/cnn_3_layer_dev['total_correct'])
plt.plot(cnn_5_layer_dev['correct_preds']/cnn_5_layer_dev['total_correct'])
plt.title('accuracy for different models')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['1 layer CNN', '3 layer CNN','5 layer CNN'], loc='lower right')
plt.show()
